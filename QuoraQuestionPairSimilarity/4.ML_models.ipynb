# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import sqlite3
from sqlalchemy import create_engine # database connection
import csv
import os
warnings.filterwarnings("ignore")
import datetime as dt
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier

from matplotlib import pyplot
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from scipy import stats
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import SGDClassifier
# from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve, auc, roc_curve

# %% [markdown]
# <h1>4. Machine Learning Models </h1>

# %% [markdown]
# <h2> 4.1 Reading data from file and storing into sql table </h2>

# %%
#Creating db file from csv. We could have used data from the csv file itself - using a db just for learning purpose
if not os.path.isfile('train.db'):
    disk_engine = create_engine('sqlite:///train.db')
    start = dt.datetime.now()
    chunksize = 90000
    j = 0
    index_start = 1
    for df in pd.read_csv('final_features.csv', names=['Unnamed: 0','id','is_duplicate','cwc_min','cwc_max','csc_min','csc_max','ctc_min','ctc_max','last_word_eq','first_word_eq','abs_len_diff','mean_len','token_set_ratio','token_sort_ratio','fuzz_ratio','fuzz_partial_ratio','longest_substr_ratio','freq_qid1','freq_qid2','q1len','q2len','q1_n_words','q2_n_words','word_Common','word_Total','word_share','freq_q1+q2','freq_q1-q2','0_x','1_x','2_x','3_x','4_x','5_x','6_x','7_x','8_x','9_x','10_x','11_x','12_x','13_x','14_x','15_x','16_x','17_x','18_x','19_x','20_x','21_x','22_x','23_x','24_x','25_x','26_x','27_x','28_x','29_x','30_x','31_x','32_x','33_x','34_x','35_x','36_x','37_x','38_x','39_x','40_x','41_x','42_x','43_x','44_x','45_x','46_x','47_x','48_x','49_x','50_x','51_x','52_x','53_x','54_x','55_x','56_x','57_x','58_x','59_x','60_x','61_x','62_x','63_x','64_x','65_x','66_x','67_x','68_x','69_x','70_x','71_x','72_x','73_x','74_x','75_x','76_x','77_x','78_x','79_x','80_x','81_x','82_x','83_x','84_x','85_x','86_x','87_x','88_x','89_x','90_x','91_x','92_x','93_x','94_x','95_x','96_x','97_x','98_x','99_x','100_x','101_x','102_x','103_x','104_x','105_x','106_x','107_x','108_x','109_x','110_x','111_x','112_x','113_x','114_x','115_x','116_x','117_x','118_x','119_x','120_x','121_x','122_x','123_x','124_x','125_x','126_x','127_x','128_x','129_x','130_x','131_x','132_x','133_x','134_x','135_x','136_x','137_x','138_x','139_x','140_x','141_x','142_x','143_x','144_x','145_x','146_x','147_x','148_x','149_x','150_x','151_x','152_x','153_x','154_x','155_x','156_x','157_x','158_x','159_x','160_x','161_x','162_x','163_x','164_x','165_x','166_x','167_x','168_x','169_x','170_x','171_x','172_x','173_x','174_x','175_x','176_x','177_x','178_x','179_x','180_x','181_x','182_x','183_x','184_x','185_x','186_x','187_x','188_x','189_x','190_x','191_x','192_x','193_x','194_x','195_x','196_x','197_x','198_x','199_x','200_x','201_x','202_x','203_x','204_x','205_x','206_x','207_x','208_x','209_x','210_x','211_x','212_x','213_x','214_x','215_x','216_x','217_x','218_x','219_x','220_x','221_x','222_x','223_x','224_x','225_x','226_x','227_x','228_x','229_x','230_x','231_x','232_x','233_x','234_x','235_x','236_x','237_x','238_x','239_x','240_x','241_x','242_x','243_x','244_x','245_x','246_x','247_x','248_x','249_x','250_x','251_x','252_x','253_x','254_x','255_x','256_x','257_x','258_x','259_x','260_x','261_x','262_x','263_x','264_x','265_x','266_x','267_x','268_x','269_x','270_x','271_x','272_x','273_x','274_x','275_x','276_x','277_x','278_x','279_x','280_x','281_x','282_x','283_x','284_x','285_x','286_x','287_x','288_x','289_x','290_x','291_x','292_x','293_x','294_x','295_x','296_x','297_x','298_x','299_x','300_x','301_x','302_x','303_x','304_x','305_x','306_x','307_x','308_x','309_x','310_x','311_x','312_x','313_x','314_x','315_x','316_x','317_x','318_x','319_x','320_x','321_x','322_x','323_x','324_x','325_x','326_x','327_x','328_x','329_x','330_x','331_x','332_x','333_x','334_x','335_x','336_x','337_x','338_x','339_x','340_x','341_x','342_x','343_x','344_x','345_x','346_x','347_x','348_x','349_x','350_x','351_x','352_x','353_x','354_x','355_x','356_x','357_x','358_x','359_x','360_x','361_x','362_x','363_x','364_x','365_x','366_x','367_x','368_x','369_x','370_x','371_x','372_x','373_x','374_x','375_x','376_x','377_x','378_x','379_x','380_x','381_x','382_x','383_x','0_y','1_y','2_y','3_y','4_y','5_y','6_y','7_y','8_y','9_y','10_y','11_y','12_y','13_y','14_y','15_y','16_y','17_y','18_y','19_y','20_y','21_y','22_y','23_y','24_y','25_y','26_y','27_y','28_y','29_y','30_y','31_y','32_y','33_y','34_y','35_y','36_y','37_y','38_y','39_y','40_y','41_y','42_y','43_y','44_y','45_y','46_y','47_y','48_y','49_y','50_y','51_y','52_y','53_y','54_y','55_y','56_y','57_y','58_y','59_y','60_y','61_y','62_y','63_y','64_y','65_y','66_y','67_y','68_y','69_y','70_y','71_y','72_y','73_y','74_y','75_y','76_y','77_y','78_y','79_y','80_y','81_y','82_y','83_y','84_y','85_y','86_y','87_y','88_y','89_y','90_y','91_y','92_y','93_y','94_y','95_y','96_y','97_y','98_y','99_y','100_y','101_y','102_y','103_y','104_y','105_y','106_y','107_y','108_y','109_y','110_y','111_y','112_y','113_y','114_y','115_y','116_y','117_y','118_y','119_y','120_y','121_y','122_y','123_y','124_y','125_y','126_y','127_y','128_y','129_y','130_y','131_y','132_y','133_y','134_y','135_y','136_y','137_y','138_y','139_y','140_y','141_y','142_y','143_y','144_y','145_y','146_y','147_y','148_y','149_y','150_y','151_y','152_y','153_y','154_y','155_y','156_y','157_y','158_y','159_y','160_y','161_y','162_y','163_y','164_y','165_y','166_y','167_y','168_y','169_y','170_y','171_y','172_y','173_y','174_y','175_y','176_y','177_y','178_y','179_y','180_y','181_y','182_y','183_y','184_y','185_y','186_y','187_y','188_y','189_y','190_y','191_y','192_y','193_y','194_y','195_y','196_y','197_y','198_y','199_y','200_y','201_y','202_y','203_y','204_y','205_y','206_y','207_y','208_y','209_y','210_y','211_y','212_y','213_y','214_y','215_y','216_y','217_y','218_y','219_y','220_y','221_y','222_y','223_y','224_y','225_y','226_y','227_y','228_y','229_y','230_y','231_y','232_y','233_y','234_y','235_y','236_y','237_y','238_y','239_y','240_y','241_y','242_y','243_y','244_y','245_y','246_y','247_y','248_y','249_y','250_y','251_y','252_y','253_y','254_y','255_y','256_y','257_y','258_y','259_y','260_y','261_y','262_y','263_y','264_y','265_y','266_y','267_y','268_y','269_y','270_y','271_y','272_y','273_y','274_y','275_y','276_y','277_y','278_y','279_y','280_y','281_y','282_y','283_y','284_y','285_y','286_y','287_y','288_y','289_y','290_y','291_y','292_y','293_y','294_y','295_y','296_y','297_y','298_y','299_y','300_y','301_y','302_y','303_y','304_y','305_y','306_y','307_y','308_y','309_y','310_y','311_y','312_y','313_y','314_y','315_y','316_y','317_y','318_y','319_y','320_y','321_y','322_y','323_y','324_y','325_y','326_y','327_y','328_y','329_y','330_y','331_y','332_y','333_y','334_y','335_y','336_y','337_y','338_y','339_y','340_y','341_y','342_y','343_y','344_y','345_y','346_y','347_y','348_y','349_y','350_y','351_y','352_y','353_y','354_y','355_y','356_y','357_y','358_y','359_y','360_y','361_y','362_y','363_y','364_y','365_y','366_y','367_y','368_y','369_y','370_y','371_y','372_y','373_y','374_y','375_y','376_y','377_y','378_y','379_y','380_y','381_y','382_y','383_y'], chunksize=chunksize, iterator=True, encoding='utf-8', ):
        df.index += index_start
        j+=1
        print('{} rows'.format(j*chunksize))
        df.to_sql('data', disk_engine, if_exists='append')
        index_start = df.index[-1] + 1

# %%
#http://www.sqlitetutorial.net/sqlite-python/create-tables/
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None


def checkTableExists(dbcon):
    cursr = dbcon.cursor()
    str = "select name from sqlite_master where type='table'"
    table_names = cursr.execute(str)
    print("Tables in the databse:")
    tables =table_names.fetchall() 
    print(tables[0][0])
    return(len(tables))

# %%
read_db = 'train.db'
conn_r = create_connection(read_db)
checkTableExists(conn_r)
conn_r.close()
# Out:
# Tables in the databse:
# data

# %%
# using 100,000 records to train
if os.path.isfile(read_db):
    conn_r = create_connection(read_db)
    if conn_r is not None:
        # for selecting first 1M rows
        # data = pd.read_sql_query("""SELECT * FROM data LIMIT 100001;""", conn_r)
        
        # for selecting random points
        data = pd.read_sql_query("SELECT * From data ORDER BY RANDOM() LIMIT 100001;", conn_r)
        conn_r.commit()
        conn_r.close()

# %%
# remove the first row 
data.drop(data.index[0], inplace=True)
y_true = data['is_duplicate']
data.drop(['Unnamed: 0', 'id','index','is_duplicate'], axis=1, inplace=True)

# %%
data.head()
# Out:
#              cwc_min            cwc_max            csc_min            csc_max  \
# 1  0.799984000319994  0.666655555740738  0.999975000624984  0.799984000319994
# 2  0.399992000159997  0.333327777870369  0.749981250468738  0.428565306209911
# 3  0.799984000319994  0.666655555740738  0.249993750156246  0.166663888935184
# 4  0.499975001249937  0.249993750156246                0.0                0.0
# 5  0.399992000159997  0.285710204139941                0.0                0.0
#
#              ctc_min            ctc_max last_word_eq first_word_eq  \
# 1  0.799992000079999  0.727266115762584          1.0           1.0
# 2      0.49999500005  0.416663194473379          1.0           0.0
# 3  0.555549382784636  0.416663194473379          0.0           0.0
# 4  0.166663888935184  0.124998437519531          1.0           0.0
# 5  0.222219753113854   0.13333244445037          0.0           0.0
#
#   abs_len_diff mean_len        ...                      374_y  \
# ...

# %% [markdown]
# <h2> 4.2 Converting strings to numerics </h2>

# %%
# after we read from sql table each entry was read in as a string
# we convert all the features into numeric before applying any model
cols = list(data.columns)
# for i in cols:
#     data[i] = data[i].apply(pd.to_numeric)
#     print(i)
    
data = pd.DataFrame(np.array(data.values,dtype=np.float64),columns=cols)

# %%
# https://stackoverflow.com/questions/7368789/convert-all-strings-in-a-list-to-int
y_true = list(map(int, y_true.values))

# %% [markdown]
# <h2> 4.3 Random train test split( 70:30) </h2>

# %%
X_train,X_test, y_train, y_test = train_test_split(data, y_true, stratify=y_true, test_size=0.3)

# %%
print("Number of data points in train data :",X_train.shape)
print("Number of data points in test data :",X_test.shape)
# Out:
# Number of data points in train data : (70000, 794)
# Number of data points in test data : (30000, 794)

# %%
print("-"*10, "Distribution of output variable in train data", "-"*10)
train_distr = Counter(y_train)
train_len = len(y_train)
print("Class 0: ",int(train_distr[0])/train_len,"Class 1: ", int(train_distr[1])/train_len)
print("-"*10, "Distribution of output variable in train data", "-"*10)
test_distr = Counter(y_test)
test_len = len(y_test)
print("Class 0: ",int(test_distr[1])/test_len, "Class 1: ",int(test_distr[1])/test_len)
# Out:
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.6283857142857143 Class 1:  0.37161428571428573
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.3716333333333333 Class 1:  0.3716333333333333

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    plt.figure(figsize=(20,4))
    
    labels = [1,2]
    # representing A in heatmap format
    cmap=sns.light_palette("blue")
    plt.subplot(1, 3, 1)
    sns.heatmap(C, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")
    
    plt.subplot(1, 3, 2)
    sns.heatmap(B, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")
    
    plt.subplot(1, 3, 3)
    # representing B in heatmap format
    sns.heatmap(A, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")
    
    plt.show()

# %% [markdown]
# <h2> 4.4 Building a random model (Finding worst-case log-loss) </h2> <br>
# The KPI is logloss and logloss can lie between 0 and infinity. So we are creating a dumb model to understand the upper bound for the logloss value. If say for instance, the logloss from the dumb model is 0.50 then we know that the model we build should have a logloss value between 0 and 0.50 - the closer it is to 0 the better the model is and the closer it is to 0.50 the worse the model is.

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
# we create a output array that has exactly same size as the CV data
predicted_y = np.zeros((test_len,2))
for i in range(test_len):
    rand_probs = np.random.rand(1,2)
    predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test, predicted_y, eps=1e-15))

predicted_y =np.argmax(predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Log loss on Test Data using Random Model 0.8835667258101775

# %% [markdown]
# <h2> 4.4 Logistic Regression with hyperparameter tuning </h2><br>
# The number of dimensions we have is close to 800, which is medium sized. This is not as high as 2000 dimensions and at the same time this is not as small as 30 dimensions. Since this is medium sized we do not have to restrict ourselves only to linear models. We can try Logistic Regression, Linear SVM, GBDT etc.

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


log_error_array=[]
for i in alpha:
    #SGD Classifier with logloss is Logistic Regression.
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    #whenever we have logloss we need to calibrate our model
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.5960094973512751
# For values of alpha =  0.0001 The log loss is: 0.516362347709739
# For values of alpha =  0.001 The log loss is: 0.5224361722744701
# For values of alpha =  0.01 The log loss is: 0.5242901286229313
# For values of alpha =  0.1 The log loss is: 0.5234959871026766
# For values of alpha =  1 The log loss is: 0.5097388257795662
# For values of alpha =  10 The log loss is: 0.5191918307608909
# For values of best alpha =  1 The train log loss is: 0.5012189991539576
# For values of best alpha =  1 The test log loss is: 0.5097388257795662
# Total number of data points : 30000

# %% [markdown]
# __Observation:__ There is not much of a difference in the logloss values between train and test set which means the model is neither overfitting nor underfitting.
# <br>The precision is almost 75% for class 1 and almost 70% for class 2, which is slightly less than class 1. The recall for class 1 is fairly high at 87% but for class 2 it is fairly low at less than 50% - this is cause for concern - of all the points belonging to class 2 the model is predicting less than 50% correctly.
# <br>Overall the numbers for class 1 seems better than class 2.
#
# Also the value is significantly less than the logloss value of 0.88 generated by the random model.
#
# <h2> 4.5 Linear SVM with hyperparameter tuning </h2>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


log_error_array=[]
for i in alpha:
    #SGDClassifier with hinge loss is LinearSVM
    clf = SGDClassifier(alpha=i, penalty='l1', loss='hinge', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='hinge', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6598192493560068
# For values of alpha =  0.0001 The log loss is: 0.48730602995334704
# For values of alpha =  0.001 The log loss is: 0.5229074919742335
# For values of alpha =  0.01 The log loss is: 0.571181875463814
# For values of alpha =  0.1 The log loss is: 0.5994018384348223
# For values of alpha =  1 The log loss is: 0.6391493877153184
# For values of alpha =  10 The log loss is: 0.6540919012601972
# For values of best alpha =  0.0001 The train log loss is: 0.47398952386865434
# For values of best alpha =  0.0001 The test log loss is: 0.48730602995334704
# Total number of data points : 30000

# %% [markdown]
# __Observation:__ <br>
# We got a slightly better performance with Linear SVM. We tend to have the same problem with recall as we had with logistic regression.
#
# The precision for class 2 has slightly improved. The recall for class 1 is very good at 90% but the recall for class 2 is still bad at less than 50%.
#
# Since the dimensions are not high, we can try a complex model such as XGBoost, which might improve the recall score for class 2.
#
# <h2> 4.6 XGBoost </h2>

# %%
import xgboost as xgb
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

d_train = xgb.DMatrix(X_train, label=y_train)
d_test = xgb.DMatrix(X_test, label=y_test)

watchlist = [(d_train, 'train'), (d_test, 'valid')]

bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, verbose_eval=10)

xgdmat = xgb.DMatrix(X_train,y_train)
predict_y = bst.predict(d_test)
print("The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# [0]	train-logloss:0.684655	valid-logloss:0.684724
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# [10]	train-logloss:0.615267	valid-logloss:0.615919
# [20]	train-logloss:0.564578	valid-logloss:0.565625
# [30]	train-logloss:0.526588	valid-logloss:0.527958
# [40]	train-logloss:0.497363	valid-logloss:0.499031
# [50]	train-logloss:0.474411	valid-logloss:0.476355
# [60]	train-logloss:0.456057	valid-logloss:0.458153
# [70]	train-logloss:0.441509	valid-logloss:0.443739
# [80]	train-logloss:0.429364	valid-logloss:0.431755
# [90]	train-logloss:0.419655	valid-logloss:0.422194
# [100]	train-logloss:0.411413	valid-logloss:0.414091
# [110]	train-logloss:0.404762	valid-logloss:0.407646
# [120]	train-logloss:0.39908	valid-logloss:0.402206
# [130]	train-logloss:0.394425	valid-logloss:0.397764
# [140]	train-logloss:0.390492	valid-logloss:0.39398
# ...

# %% [markdown]
# __Observation:__ <br>The final logloss is 0.357, which is better than the values got from linear models. The linear models tend to have a bias or underfitting problem, which GBDT seems to have corrected for.

# %%
predicted_y =np.array(predict_y>0.5,dtype=int)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Total number of data points : 30000

# %% [markdown]
# __Observation:__
# The precision value for class 2 has improved a lot to 90% and the recall for class 2 has also improved beyond 50% to close to 69%.
# <h1> 5. Lets try out </h1>
# 1. Models (Logistic regression, Linear-SVM) with simple TF-IDF vectors instead of TD_IDF weighted word2Vec.
# 2. Hyperparameter tune XgBoost using RandomSearch to reduce the log-loss.

# %% [markdown]
# <h2> Define functions </h2>

# %%
def get_data(n=500):
    df = pd.read_csv("train.csv", nrows=n)
    
    return df

# %%
def split_data(data, y):
    
    X_train, X_test, y_train, y_test = train_test_split(data, y, stratify=y, test_size=0.3)
#     X_train, X_test, y_train, y_test = tts(data, y, stratify=y, test_size=0.3)
    
    print("Number of data points in train data :",X_train.shape)
    print("Number of data points in test data :",X_test.shape)
    
    print("-"*10, "Distribution of output variable in train data", "-"*10)
    train_distr = Counter(y_train)
    train_len = len(y_train)
    
    print("Class 0: ",int(train_distr[0])/train_len,"Class 1: ", int(train_distr[1])/train_len)
    print("-"*10, "Distribution of output variable in train data", "-"*10)
    
    test_distr = Counter(y_test)
    test_len = len(y_test)
    print("Class 0: ",int(test_distr[1])/test_len, "Class 1: ",int(test_distr[1])/test_len)
    
    return X_train,X_test, y_train, y_test

# %%
def vectorize_using_tfidf(questions):

    tfidf = TfidfVectorizer(ngram_range=(1,3), stop_words='english', min_df=0.00009, max_features=100000, norm="l2")
    
    tfidf_questions = tfidf.fit_transform(questions)
    
    return tfidf_questions

# %% [markdown]
# <h2>5.1 Try out models (Logistic regression, Linear-SVM) with simple TF-IDF vectors instead of TD_IDF weighted word2Vec. </h2>

# %% [markdown]
# <h3> 5.1.0 Vectorize data using TFIDF and Save to a csv file</h3>

# %%
# get data
n=50000
df = get_data(n)

# vectorize the questions using tfidf
questions = list(df['question1']) + list(df['question2'])
tfidf_question = vectorize_using_tfidf(questions)

# %%
#the first part of the sparse array tfidf_question contains matrix related to question1 and the last part contains 
#matrix related to question2
q1_end = int((len(tfidf_question.A))/2)
df['q1_tfidf_feats'] = list(tfidf_question.A[0:q1_end])
df['q2_tfidf_feats'] = list(tfidf_question.A[q1_end:])

# %%
#tfidf vectorized features for question1 and question2 are stored in separate columns in df. These are mutli dimensional arrays
#that needs to be stored as separate columns for the model to process. We will copy them to a separate dataframe and merge 
#them later to a single dataframe.
tfidf_feats_q1 = pd.DataFrame(df.q1_tfidf_feats.values.tolist(), index= df.index)
tfidf_feats_q2 = pd.DataFrame(df.q2_tfidf_feats.values.tolist(), index= df.index)

# %%
complex_feats = pd.read_csv("nlp_features_train.csv",encoding='latin-1', nrows=n)
simple_feats = pd.read_csv("df_fe_without_preprocessing_train.csv",encoding='latin-1', nrows=n)

# %%
simple_feats = simple_feats.drop(['qid1','qid2','question1','question2'],axis=1)
complex_feats = complex_feats.drop(['qid1','qid2','question1','question2','is_duplicate'],axis=1)
df = df.drop(['qid1','qid2','question1','question2','is_duplicate'],axis=1)

# %%
tfidf_feats_q1['id']=df['id']
tfidf_feats_q2['id']=df['id']
complex_feats  = complex_feats.merge(simple_feats, on='id',how='left')
tfidf_feats  = tfidf_feats_q2.merge(tfidf_feats_q2, on='id',how='left')
result  = complex_feats.merge(tfidf_feats, on='id',how='left')
result.to_csv('with_tfidf_features.csv')

# %% [markdown]
# <h3> 5.1.1 Logistic Regression</h3>
#
# <h4> 5.1.1.1 Train Test Split Data</h4>

# %%
n = 50000
df = pd.read_csv("with_tfidf_features.csv", nrows=n)
df.drop(df.index[0], inplace=True)
y = df['is_duplicate']
df.drop(['Unnamed: 0', 'id','is_duplicate'], axis=1, inplace=True)

cols = list(df.columns)
df = pd.DataFrame(np.array(df.values,dtype=np.float64),columns=cols)

y = list(map(int, y.values))
X_train, X_test, y_train, y_test = split_data(df, y)
# Out:
# Number of data points in train data : (34999, 22982)
# Number of data points in test data : (15000, 22982)
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.6270179147975656 Class 1:  0.37298208520243437
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.373 Class 1:  0.373

# %% [markdown]
# <h4> 5.1.1.2 Train using Logistic Regression</h4>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

log_error_array=[]
for i in alpha:
    #SGD Classifier with logloss is Logistic Regression.
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)

    #whenever we have logloss we need to calibrate our model
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.4682528642589155
# For values of alpha =  0.0001 The log loss is: 0.4632993945275719
# For values of alpha =  0.001 The log loss is: 0.4608304854506673
# For values of alpha =  0.01 The log loss is: 0.46364787604978447
# For values of alpha =  0.1 The log loss is: 0.4556127441978947
# For values of alpha =  1 The log loss is: 0.4879452558866526
# For values of alpha =  10 The log loss is: 0.5477421161694482
# For values of best alpha =  0.1 The train log loss is: 0.4582150835912711
# For values of best alpha =  0.1 The test log loss is: 0.4556127441978947
# Total number of data points : 15000

# %% [markdown]
# <h3> 5.1.2 Linear SVM</h3>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

log_error_array=[]
for i in alpha:
    #SGDClassifier with hinge loss is LinearSVM
    clf = SGDClassifier(alpha=i, penalty='l1', loss='hinge', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='hinge', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.46667576476718925
# For values of alpha =  0.0001 The log loss is: 0.47763475197382954
# For values of alpha =  0.001 The log loss is: 0.4873027718592526
# For values of alpha =  0.01 The log loss is: 0.49335965391755515
# For values of alpha =  0.1 The log loss is: 0.48016164795742516
# For values of alpha =  1 The log loss is: 0.5749803628101195
# For values of alpha =  10 The log loss is: 0.5995249255947614
# For values of best alpha =  1e-05 The train log loss is: 0.4714448080639508
# For values of best alpha =  1e-05 The test log loss is: 0.46667576476718925
# Total number of data points : 15000

# %% [markdown]
# <h2>5.2. Hyperparameter tune XgBoost using RandomSearch to reduce the log-loss </h2>
#
# <h4> 5.2.1 Train Test Split Data</h4>

# %%
read_db = 'train.db'
# using 100,000 records to train
if os.path.isfile(read_db):
    conn_r = create_connection(read_db)
    if conn_r is not None:
        # for selecting random points
        data = pd.read_sql_query("SELECT * From data ORDER BY RANDOM() LIMIT 100001;", conn_r)
#         data = pd.read_sql_query("SELECT * From data ORDER BY RANDOM() LIMIT 1001;", conn_r)
        conn_r.commit()
        conn_r.close()

# remove the first row 
data.drop(data.index[0], inplace=True)
y = data['is_duplicate']
data.drop(['Unnamed: 0', 'id','index','is_duplicate'], axis=1, inplace=True)

cols = list(data.columns)
    
data = pd.DataFrame(np.array(data.values,dtype=np.float64),columns=cols)

y = list(map(int, y.values))

X_train, X_test, y_train, y_test = split_data(data, y)
# Out:
# Number of data points in train data : (70000, 794)
# Number of data points in test data : (30000, 794)
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.6311571428571429 Class 1:  0.36884285714285714
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.36883333333333335 Class 1:  0.36883333333333335

# %% [markdown]
# <h4> 5.2.2 Train using XGBoost</h4>

# %% [markdown]
# <h5> Step 1- Tune n_estimators </h5>

# %%
def plot_results(means, stds, params, x_axis_values, title, xlabel, ylabel):
    for mean, stdev, param in zip(means, stds, params):
        print("{} ({}) with: {}".format(mean, stdev, param))
    # plot
    pyplot.errorbar(x_axis_values, means, yerr=stds)
    pyplot.title(title)
    pyplot.xlabel(xlabel)
    pyplot.ylabel(ylabel)

# %%
# grid search
model = XGBClassifier()
n_estimators = range(50, 400, 50)
param_grid = dict(n_estimators=n_estimators)

kfold   = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)

grid_search = GridSearchCV(model, param_grid, scoring="neg_log_loss", n_jobs=-1, cv=kfold)

grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: {} using {}".format(-1*grid_result.best_score_, grid_result.best_params_))
means = -1 * grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("{} ({}) with: {}".format(mean, stdev, param))
# # plot
# pyplot.errorbar(n_estimators, means, yerr=stds)
# pyplot.title("XGBoost n_estimators vs Log Loss")
# pyplot.xlabel('n_estimators')
# pyplot.ylabel('Log Loss')
title = 'XGBoost n_estimators vs Log Loss'
xlabel = 'n_estimators'
ylabel = 'Log Loss'
plot_results(means, stds, params, n_estimators, title, xlabel, ylabel)
# Out:
# Best: 0.34087075125009175 using {'n_estimators': 350}
# 0.38042182287493653 (0.003202757085323801) with: {'n_estimators': 50}
# 0.36056534587959427 (0.0037211725209920347) with: {'n_estimators': 100}
# 0.3518103257439361 (0.004019313648050884) with: {'n_estimators': 150}
# 0.34720884073128566 (0.004285248633958572) with: {'n_estimators': 200}
# 0.3442107170296131 (0.0044240664605963475) with: {'n_estimators': 250}
# 0.3421739939262711 (0.0046556304100174245) with: {'n_estimators': 300}
# 0.34087075125009175 (0.0047065431867308605) with: {'n_estimators': 350}

# %% [markdown]
#  <h5>Step 2- Tune the size of decision trees based on the best n_estimator got from the previous step </h5>

# %%
# grid search
model = XGBClassifier(n_estimators=350)
max_depth = range(1, 11, 2)

param_grid = dict(max_depth=max_depth)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=7)

grid_search = GridSearchCV(model, param_grid, scoring="neg_log_loss", n_jobs=-1, cv=kfold, verbose=1)

grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: {} using {}".format(-1*grid_result.best_score_, grid_result.best_params_))
means = -1 * grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

# plot
title = 'XGBoost max_depth vs Log Loss'
xlabel = 'max_depth'
ylabel = 'Log Loss'
plot_results(means, stds, params, max_depth, title, xlabel, ylabel)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed: 151.0min finished
# Best: 0.33223466547333863 using {'max_depth': 7}
# 0.38542235997916513 (0.0022951384971092244) with: {'max_depth': 1}
# 0.3415827474091639 (0.0028915957996771442) with: {'max_depth': 3}
# 0.33238942939102184 (0.002613264435211076) with: {'max_depth': 5}
# 0.33223466547333863 (0.0035106021033548163) with: {'max_depth': 7}
# 0.35872992061929854 (0.005263645405003521) with: {'max_depth': 9}

# %% [markdown]
#  <h5> Step 3 - Tune learning rate based on the best size of decision trees & n_estimator got from the previous steps </h5>

# %%
# grid search
model = XGBClassifier(n_estimators=350, max_depth=7)

learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]
param_grid = dict(learning_rate=learning_rate)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=7)

grid_search = GridSearchCV(model, param_grid, scoring="neg_log_loss", n_jobs=-1, cv=kfold)
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: {} using {}".format(-1*grid_result.best_score_, grid_result.best_params_))
means = -1 * grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

# plot
title = 'XGBoost learning_rate vs Log Loss'
xlabel = 'learning_rate'
ylabel = 'Log Loss'
plot_results(means, stds, params, learning_rate, title, xlabel, ylabel)
# Out:
# Best: 0.33223466547333863 using {'learning_rate': 0.1}
# 0.6764557050159999 (9.66535984074017e-05) with: {'learning_rate': 0.0001}
# 0.5655175384457622 (0.0008766837853040426) with: {'learning_rate': 0.001}
# 0.354654187000636 (0.0024238058353183672) with: {'learning_rate': 0.01}
# 0.33223466547333863 (0.0035106021033548163) with: {'learning_rate': 0.1}
# 0.3682995195098535 (0.004607984796017068) with: {'learning_rate': 0.2}
# 0.41872999931928795 (0.005321096875936724) with: {'learning_rate': 0.3}

# %% [markdown]
#  <h5>Step 4 - Train the model using parameters from the above steps </h5>

# %%
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.1
params['max_depth'] = 7
params['n_estimators'] = 350

d_train = xgb.DMatrix(X_train, label=y_train)
d_test = xgb.DMatrix(X_test, label=y_test)

watchlist = [(d_train, 'train'), (d_test, 'valid')]

bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, verbose_eval=10)

xgdmat = xgb.DMatrix(X_train,y_train)
predict_y = bst.predict(d_test)
print("The test log loss is:",log_loss(y_test, predict_y, eps=1e-15))
# Out:
# [0]	train-logloss:0.645118	valid-logloss:0.646735
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# [10]	train-logloss:0.426754	valid-logloss:0.44122
# [20]	train-logloss:0.360631	valid-logloss:0.38465
# [30]	train-logloss:0.332009	valid-logloss:0.363615
# [40]	train-logloss:0.315683	valid-logloss:0.354773
# [50]	train-logloss:0.302602	valid-logloss:0.349715
# [60]	train-logloss:0.291344	valid-logloss:0.346343
# [70]	train-logloss:0.279494	valid-logloss:0.343711
# [80]	train-logloss:0.269097	valid-logloss:0.341669
# [90]	train-logloss:0.25838	valid-logloss:0.34031
# [100]	train-logloss:0.246664	valid-logloss:0.338839
# [110]	train-logloss:0.235485	valid-logloss:0.33758
# [120]	train-logloss:0.226516	valid-logloss:0.336703
# [130]	train-logloss:0.218084	valid-logloss:0.335972
# [140]	train-logloss:0.209806	valid-logloss:0.335299
# ...

# %%
predicted_y =np.array(predict_y>0.5,dtype=int)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Total number of data points : 30000

# %% [markdown]
# ## Try out models (Logistic regression, Linear-SVM) with simple TF-IDF vectors instead of TD_IDF weighted word2Vec -
# ### Logistic Regression
# 1. The train log loss is: 0.4582150835912711
# 2. The test log loss is: 0.4556127441978947
#
# ### Linear SVM
# 1. The train log loss is: 0.4714448080639508
# 2. The test log loss is: 0.46667576476718925
#
# ## Tune Hyperparameter for XgBoost using RandomSearch
# 1. The train log loss is: 0.330945
# 2. The test log loss is: 0.33155151189066834
#
# ## Conclusion
# XGBoost seems to perform better
